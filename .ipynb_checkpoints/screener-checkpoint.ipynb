# %%
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt

plt.close('all')

# %%
i = ['MMM', 'AXP', 'AMGN', 'BA', 'CAT', 'CVX', 'CSCO', 'KO', 'DOW', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'JPM', 'MCD', 'MRK',
'NKE', 'PG', 'CRM', 'TRV', 'UNH', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'F', 'HYG', 'GE', 'SPY', 'SLV', 'QQQ', 'EEM', 'HYG', 'TSLA',
'SLV', 'AAPL']

# %%
h = []
for i in w.split('ET'):
    h.append(i.split(' ')[1].split('\t')[0])

# %%
h = h[1:]

# %%
h[60]
# Out:
# ''

# %%
h.pop(60)
# Out:
# ''

# %%
h
# Out:
# ['TSLA',
#  'AAPL',
#  'BA',
#  'GE',
#  'BABA',
#  'PLTR',
#  'DKNG',
#  'NKLA',
#  'AAL',
#  'SPCE',
#  'MSFT',
#  'TGT',
#  'CCL',
#  'F',
#  'FCEL',
#  'AMD',
#  'SNAP',
#  'GM',
#  'RIOT',
#  'WFC',
#  'NCLH',
#  'MRO',
#  'BYND',
#  'M',
#  'BAC',
#  'DIS',
#  'VALE',
#  'PCG',
#  'AMZN',
#  'MU',
#  'RIDE',
#  'FB',
#  'FTAI',
#  'ACB',
#  'OXY',
#  'NVDA',
#  'WMT',
#  'LOW',
#  'SDC',
#  'DAL',
#  'XOM',
#  'PLUG',
#  'WKHS',
#  'C',
#  'MRNA',
#  'BLNK',
#  'COST',
#  'XPEV',
#  'GOLD',
#  'HYLN',
#  'JMIA',
#  'ZM',
#  'MARA',
#  'KNDI',
#  'JPM',
#  'CRM',
#  'JD',
#  'LI',
#  'UAL',
#  'TJX',
#  'UBER',
#  'CVS',
#  'NFLX',
#  'MNKKQ',
#  'TWTR',
#  'INTC',
#  'AMC',
#  'QCOM',
#  'SQ',
#  'KSS',
#  'RKT',
#  'JWN',
#  'HD',
#  'LYFT',
#  'PTON',
#  'ATVI',
#  'ROKU',
#  'PDD',
#  'SOLO',
#  'MGM',
#  'PBR',
#  'PENN',
#  'TEAM',
#  'WBA',
#  'GRPN',
#  'INO',
#  'ADBE',
#  'SBUX',
#  'COTY',
#  'CHWY',
#  'SONO',
#  'WYNN',
#  'X',
#  'TLRY',
#  'CSCO',
#  'T',
# ...

# %%
total = h + i

# %%
len(total)
# Out:
# 137

# %%
total = set(total)

# %%
len(total)
# Out:
# 122

# %%
for i in total:
    #get data on this ticker
    tickerData = yf.Ticker(i)

    #get the historical prices for this ticker
    tickerDf = tickerData.history(period='1d', start='2020-1-1', end='2020-11-18')
    tickerDf['Open'].plot(subplots=True)
    plt.tight_layout()
    print(i)
    plt.show(i)
# Out:
# TSLA
# AAPL
# BA
# GE
# BABA
# PLTR
# DKNG
# NKLA
# AAL
# SPCE
# MSFT
# TGT
# CCL
# F
# FCEL
# AMD
# SNAP
# GM
# RIOT
# WFC
# NCLH
# MRO
# BYND
# M
# BAC
# DIS
# VALE
# PCG
# AMZN
# MU
# RIDE
# FB
# FTAI
# ACB
# OXY
# NVDA
# WMT
# LOW
# SDC
# DAL
# XOM
# PLUG
# WKHS
# C
# MRNA
# BLNK
# COST
# XPEV
# GOLD
# HYLN
# JMIA
# ZM
# MARA
# KNDI
# JPM
# CRM
# JD
# LI
# UAL
# TJX
# UBER
# CVS
# NFLX
# - MNKKQ: No data found for this date range, symbol may be delisted
# MNKKQ
# TWTR
# INTC
# AMC
# QCOM
# SQ
# KSS
# RKT
# JWN
# HD
# LYFT
# PTON
# ATVI
# ROKU
# PDD
# SOLO
# MGM
# PBR
# PENN
# TEAM
# WBA
# GRPN
# INO
# ADBE
# SBUX
# COTY
# CHWY
# SONO
# WYNN
# X
# TLRY
# CSCO
# T
# SNOW
# PINS
# MMM
# AXP
# AMGN
# BA
# CAT
# CVX
# CSCO
# KO
# DOW
# GS
# HD
# HON
# IBM
# INTC
# JNJ
# JPM
# MCD
# MRK
# NKE
# PG
# CRM
# TRV
# UNH
# VZ
# V
# WBA
# WMT
# DIS
# F
# HYG
# GE
# SPY
# SLV
# QQQ
# EEM
# HYG
# TSLA
# SLV
# AAPL

# %%
# !dir
# Out:
#  Volume in drive D is Q2
#  Volume Serial Number is B63F-C207
#
#  Directory of D:\tor\Stock
#
# 11/18/2020  01:00 PM    <DIR>          .
# 11/18/2020  01:00 PM    <DIR>          ..
# 11/18/2020  11:55 AM    <DIR>          .ipynb_checkpoints
# 11/18/2020  01:00 PM         3,542,172 Untitled.ipynb
#                1 File(s)      3,542,172 bytes
#                3 Dir(s)  3,684,252,598,272 bytes free
